# %% [markdown]
# # **Data wrangling**
#
# is the process of transforming and structuring data from one raw form into a desired format
# types:
# *   discovery
# *   structuring
# *   cleaning
# *   enriching
# *   validating
# *   publishing

# %% [markdown]
# # ***Types of data***
#
#
# 1.  CSV (comma-separated values)
# 2.  EXCLE
# 3.  JASON

# %% [markdown]
# # LOADING A SAMPLE DATASET
# 1. [dataset.load_digits](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_digits.html#sklearn.datasets.load_digits)

# %%
from sklearn import datasets #load datasets
digits=datasets.load_digits() #load digits
features=digits.data
target=digits.target
features[0] #view the first observation
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %% [markdown]
# [load_iris](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html#sklearn.datasets.load_iris)

# %%
from sklearn import datasets #load datasets
iris=datasets.load_iris() #load digits
features=iris.data# features matrix
target=iris.target
features[0]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %% [markdown]
# [datasets-load-breast-cancer](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_breast_cancer.html#sklearn-datasets-load-breast-cancer)

# %%
from sklearn import datasets #load datasets
breast_cancer=datasets.load_breast_cancer() #load digits
features=breast_cancer.data
target=breast_cancer.target
features[0]
# Out:
# array([1.799e+01, 1.038e+01, 1.228e+02, 1.001e+03, 1.184e-01, 2.776e-01,
#        3.001e-01, 1.471e-01, 2.419e-01, 7.871e-02, 1.095e+00, 9.053e-01,
#        8.589e+00, 1.534e+02, 6.399e-03, 4.904e-02, 5.373e-02, 1.587e-02,
#        3.003e-02, 6.193e-03, 2.538e+01, 1.733e+01, 1.846e+02, 2.019e+03,
#        1.622e-01, 6.656e-01, 7.119e-01, 2.654e-01, 4.601e-01, 1.189e-01])

# %% [markdown]
# **Creating a Simulated Dataset**

# %% [markdown]
# 1.  [datasets.make_regression](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_regression.html#sklearn-datasets-make-regression)

# %%
from sklearn.datasets import make_regression
features,target,coefficients=make_regression(n_samples=100,
                                             n_features=3,
                                             n_informative=3,
                                             n_targets=1,
                                             noise=10,
                                             coef=True,
                                             random_state=1)
print("feature matrix:\n {}".format(features[:3]))
print("target vector:\n",format(features[:3]))
# Out:
# feature matrix:
#  [[-0.84520564 -0.0126646  -0.67124613]
#  [ 0.83600472  0.75880566  1.54335911]
#  [-0.35224985 -0.34934272 -1.1425182 ]]
# target vector:
#  [[-0.84520564 -0.0126646  -0.67124613]
#  [ 0.83600472  0.75880566  1.54335911]
#  [-0.35224985 -0.34934272 -1.1425182 ]]

# %% [markdown]
# [datasets.make_classification.](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_classification.html#sklearn-datasets-make-classification)

# %%
from sklearn.datasets import make_classification
features,target = make_classification(n_samples=100,
                                   n_features=3,
                                   n_informative=3,
                                   n_redundant=0,
                                   n_classes=2,
                                   weights=[.25,.25],
                                   random_state=1)
print("feature matrix\nc {}".format(features[:3]))
print("target vector\n {}".format(target[:3]))
# Out:
# feature matrix
# c [[ 1.06354768 -1.42632219  1.02163151]
#  [ 0.23156977  1.49535261  0.33251578]
#  [ 0.15972951  0.83533515 -0.40869554]]
# target vector
#  [1 0 0]

# %% [markdown]
# [Datasets.make_blobs](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html#sklearn.datasets.make_blobs)

# %%
from sklearn.datasets import make_blobs
features, target= make_blobs(n_samples=100,
                            n_features=2,
                            centers =3,
                            cluster_std=0.5,
                            shuffle=True,
                            random_state=1)
print("Feature matrix\n {}".format(features[:3]))
print("target vector\n {}".format(target[:3]))
# Out:
# Feature matrix
#  [[ -1.22685609   3.25572052]
#  [ -9.57463218  -4.38310652]
#  [-10.71976941  -4.20558148]]
# target vector
#  [0 1 1]

# %%
import matplotlib.pyplot as plt
plt.scatter(features[:,0],features[:,1],c=target)
plt.show()

# %% [markdown]
# # LOADIND A CSV FILE

# %%
import pandas as pd
url="https://raw.githubusercontent.com/jbrownlee/Datasets/master/iris.csv"
df=pd.read_csv(url)
df.head(3)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa

# %% [markdown]
# LOADING A EXCEL FILE

# %%
import pandas as pd
df = pd.read_excel('/content/Sample-Spreadsheet-10-rows.xls')
df.head()
# Out:
#    1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0  2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1  3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
# 2  4                                               R380      Clay Rozendal
# 3  5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4  6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
#
#      3    -213.25   38.94     35  Nunavut          Storage & Organization  \
# 0  293   457.8100  208.16  68.02  Nunavut                      Appliances
# 1  293    46.7075    8.69   2.99  Nunavut  Binders and Binder Accessories
# 2  483  1198.9710  195.99   3.99  Nunavut    Telephones and Communication
# 3  515    30.9400   21.78   5.94  Nunavut                      Appliances
# 4  515     4.4300    6.64   4.95  Nunavut              Office Furnishings
#
#     0.8
# 0  0.58
# 1  0.39
# 2  0.58
# 3  0.50
# 4  0.37

# %% [markdown]
# #  Loading a JSON File

# %%
import pandas as pd
df = pd.read_json('/content/sample_data/anscombe.json')
df.head()
# Out:
#   Series   X     Y
# 0      I  10  8.04
# 1      I   8  6.95
# 2      I  13  7.58
# 3      I   9  8.81
# 4      I  11  8.33

# %% [markdown]
# # Querying a SQL Database

# %%
import pandas as pd
import sqlite3

con=sqlite3.connect("/content/sakila_master-(2).db")
df = pd.read_sql_query("SELECT * FROM actor", con)
df.head()
# Out:
#    actor_id first_name     last_name          last_update
# 0         1   PENELOPE       GUINESS  2020-12-23 07:12:29
# 1         2       NICK      WAHLBERG  2020-12-23 07:12:29
# 2         3         ED         CHASE  2020-12-23 07:12:29
# 3         4   JENNIFER         DAVIS  2020-12-23 07:12:29
# 4         5     JOHNNY  LOLLOBRIGIDA  2020-12-23 07:12:29
